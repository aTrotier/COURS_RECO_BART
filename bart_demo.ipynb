# %%
# !apt-get -qq install -y  gcc make libfftw3-dev liblapacke-dev libpng-dev libopenblas-dev gfortran
# Out:
# Selecting previously unselected package libfftw3-long3:amd64.
# (Reading database ... 160980 files and directories currently installed.)
# Preparing to unpack .../0-libfftw3-long3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../1-libfftw3-quad3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../2-libfftw3-single3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../3-libfftw3-bin_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-bin (3.3.7-1) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../4-libfftw3-dev_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.7-1) ...
# Selecting previously unselected package liblapacke:amd64.
# Preparing to unpack .../5-liblapacke_3.7.1-4ubuntu1_amd64.deb ...
# Unpacking liblapacke:amd64 (3.7.1-4ubuntu1) ...
# Selecting previously unselected package libtmglib3:amd64.
# Preparing to unpack .../6-libtmglib3_3.7.1-4ubuntu1_amd64.deb ...
# Unpacking libtmglib3:amd64 (3.7.1-4ubuntu1) ...
# Selecting previously unselected package libtmglib-dev:amd64.
# Preparing to unpack .../7-libtmglib-dev_3.7.1-4ubuntu1_amd64.deb ...
# Unpacking libtmglib-dev:amd64 (3.7.1-4ubuntu1) ...
# Selecting previously unselected package liblapacke-dev:amd64.
# Preparing to unpack .../8-liblapacke-dev_3.7.1-4ubuntu1_amd64.deb ...
# Unpacking liblapacke-dev:amd64 (3.7.1-4ubuntu1) ...
# Setting up libtmglib3:amd64 (3.7.1-4ubuntu1) ...
# Setting up libfftw3-quad3:amd64 (3.3.7-1) ...
# Setting up libfftw3-single3:amd64 (3.3.7-1) ...
# Setting up liblapacke:amd64 (3.7.1-4ubuntu1) ...
# Setting up libfftw3-long3:amd64 (3.3.7-1) ...
# Setting up libtmglib-dev:amd64 (3.7.1-4ubuntu1) ...
# Setting up libfftw3-bin (3.3.7-1) ...
# Setting up liblapacke-dev:amd64 (3.7.1-4ubuntu1) ...
# Setting up libfftw3-dev:amd64 (3.3.7-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !git clone https://github.com/mrirecon/bart
# Out:
# Cloning into 'bart'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 11995 (delta 100), reused 127 (delta 75), pack-reused 11765
# Receiving objects: 100% (11995/11995), 7.76 MiB | 27.04 MiB/s, done.
# Resolving deltas: 100% (8711/8711), done.

# %%
cd bart
# Out:
# /content/bart

# %%
# !PARALLEL=1 make
# Out:
# make MAKESTAGE=2
# make[1]: Entering directory '/content/bart'
# CONFIGURATION MODIFIED. RUNNING FULL REBUILD.
# touch isclean
# make allclean || rm isclean
# make[2]: Entering directory '/content/bart'
# rm -f `find /content/bart/src -name "*.o"`
# rm -f /content/bart/utests/*.o
# rm -f  test_linop_matrix  test_linop  test_batchsvd  test_pattern  test_types  test_misc  test_moba  test_nlop  test_nufft  test_multind  test_flpmath  test_splines  test_linalg  test_polynom  test_window  test_conv  test_blas  test_mdfft  test_ops  test_ops_p  test_flpmath2  test_ode_bloch  test_biot_savart  test_signals  test_geom  test_iter  test_prox
# rm -f /content/bart/lib/.*.lock
# rm -f /content/bart/lib/*.a
# rm -f  bart  avg  bench  bin  bitmask  cabs  caldir  calmat  carg  casorati  cc  ccapply  cdf97  circshift  conj  conv  conway  copy  cpyphs  creal  crop  delta  ecalib  ecaltwo  estdelay  estdims  estshift  estvar  extract  fakeksp  fft  fftmod  fftrot  fftshift  filter  flatten  flip  fmac  homodyne  index  invert  itsense  join  looklocker  lrmatrix  mandelbrot  mip  moba  mobafit  nlinv  noise  normalize  nrmse  nufft  ones  pattern  phantom  pics  pocsense  poisson  pol2mask  poly  repmat  reshape  resize  rmfreq  rof  roistat  rss  rtnlinv  sake  saxpy  scale  sdot  show  signal  slice  spow  sqpics  squeeze  ssa  std  svd  tgv  threshold  toimg  traj  transpose  twixread  upat  var  vec  version  walsh  wave  wavelet  wavepsf  whiten  window  wshfl  zeros  zexp
# rm -f /content/bart/src/misc/version.inc
# rm -rf /content/bart/tests/tmp/*/
# rm -rf /content/bart/doc/dx
# rm -f /content/bart/doc/commands.txt
# touch isclean
# make[2]: Leaving directory '/content/bart'
# gcc -Wall -Wextra -MMD -MF /content/bart/src/.bart.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o /content/bart/src/bart.o /content/bart/src/bart.c
# gcc -Wall -Wextra -MMD -MF src/.show.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/show.o src/show.c
# gcc -Wall -Wextra -MMD -MF src/.slice.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/slice.o src/slice.c
# gcc -Wall -Wextra -MMD -MF src/.crop.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/crop.o src/crop.c
# gcc -Wall -Wextra -MMD -MF src/.resize.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/resize.o src/resize.c
# gcc -Wall -Wextra -MMD -MF src/.join.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/join.o src/join.c
# gcc -Wall -Wextra -MMD -MF src/.transpose.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/transpose.o src/transpose.c
# gcc -Wall -Wextra -MMD -MF src/.squeeze.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/squeeze.o src/squeeze.c
# gcc -Wall -Wextra -MMD -MF src/.flatten.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/flatten.o src/flatten.c
# gcc -Wall -Wextra -MMD -MF src/.zeros.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/zeros.o src/zeros.c
# gcc -Wall -Wextra -MMD -MF src/.ones.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/ones.o src/ones.c
# gcc -Wall -Wextra -MMD -MF src/.flip.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/flip.o src/flip.c
# gcc -Wall -Wextra -MMD -MF src/.circshift.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/circshift.o src/circshift.c
# gcc -Wall -Wextra -MMD -MF src/.extract.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/extract.o src/extract.c
# gcc -Wall -Wextra -MMD -MF src/.repmat.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/repmat.o src/repmat.c
# gcc -Wall -Wextra -MMD -MF src/.bitmask.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/bitmask.o src/bitmask.c
# gcc -Wall -Wextra -MMD -MF src/.reshape.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/reshape.o src/reshape.c
# gcc -Wall -Wextra -MMD -MF src/.version.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/version.o src/version.c
# gcc -Wall -Wextra -MMD -MF src/.delta.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/delta.o src/delta.c
# gcc -Wall -Wextra -MMD -MF src/.copy.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/copy.o src/copy.c
# gcc -Wall -Wextra -MMD -MF src/.casorati.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/casorati.o src/casorati.c
# gcc -Wall -Wextra -MMD -MF src/.vec.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/vec.o src/vec.c
# gcc -Wall -Wextra -MMD -MF src/.poly.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/poly.o src/poly.c
# gcc -Wall -Wextra -MMD -MF src/.index.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/index.o src/index.c
# gcc -Wall -Wextra -MMD -MF src/.scale.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/scale.o src/scale.c
# gcc -Wall -Wextra -MMD -MF src/.invert.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/invert.o src/invert.c
# gcc -Wall -Wextra -MMD -MF src/.conj.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/conj.o src/conj.c
# gcc -Wall -Wextra -MMD -MF src/.fmac.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/fmac.o src/fmac.c
# gcc -Wall -Wextra -MMD -MF src/.saxpy.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/saxpy.o src/saxpy.c
# gcc -Wall -Wextra -MMD -MF src/.sdot.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/sdot.o src/sdot.c
# gcc -Wall -Wextra -MMD -MF src/.spow.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/spow.o src/spow.c
# gcc -Wall -Wextra -MMD -MF src/.cpyphs.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/cpyphs.o src/cpyphs.c
# gcc -Wall -Wextra -MMD -MF src/.creal.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/creal.o src/creal.c
# gcc -Wall -Wextra -MMD -MF src/.carg.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/carg.o src/carg.c
# gcc -Wall -Wextra -MMD -MF src/.normalize.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/normalize.o src/normalize.c
# gcc -Wall -Wextra -MMD -MF src/.cdf97.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/cdf97.o src/cdf97.c
# gcc -Wall -Wextra -MMD -MF src/.pattern.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/pattern.o src/pattern.c
# gcc -Wall -Wextra -MMD -MF src/.nrmse.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/nrmse.o src/nrmse.c
# gcc -Wall -Wextra -MMD -MF src/.mip.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/mip.o src/mip.c
# gcc -Wall -Wextra -MMD -MF src/.avg.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/avg.o src/avg.c
# gcc -Wall -Wextra -MMD -MF src/.cabs.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/cabs.o src/cabs.c
# gcc -Wall -Wextra -MMD -MF src/.zexp.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/zexp.o src/zexp.c
# gcc -Wall -Wextra -MMD -MF src/.fft.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/fft.o src/fft.c
# gcc -Wall -Wextra -MMD -MF src/.fftmod.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/fftmod.o src/fftmod.c
# gcc -Wall -Wextra -MMD -MF src/.fftshift.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/fftshift.o src/fftshift.c
# gcc -Wall -Wextra -MMD -MF src/.noise.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -c -o src/noise.o src/noise.c
# ...
# ./ar_lock.sh rsU lib/libsense.a /content/bart/src/sense/recon.o
# ./ar_lock.sh rsU lib/libnoir.a /content/bart/src/noir/recon.o
# ./ar_lock.sh rsU lib/libnoir.a /content/bart/src/noir/misc.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/iter.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/lad.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/thresh.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/niht.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/itop.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/vec.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/iter5.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/misc.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/monitor.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/iter4.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/iter3.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/grad.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/realval.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/fmac.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/sum.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/waveop.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/sampling.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/decompose_complex.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/lintest.o
# ./ar_lock.sh rsU lib/libwavelet.a /content/bart/src/wavelet/wavthresh.o
# ./ar_lock.sh rsU lib/liblowrank.a /content/bart/src/lowrank/batchsvd.o
# ./ar_lock.sh rsU lib/libnoncart.a /content/bart/src/noncart/precond.o
# ./ar_lock.sh rsU lib/libnoncart.a /content/bart/src/noncart/traj.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/cc.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/walsh.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/direct.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/calmat.o
# ar: ./ar_lock.sh rsU lib/libsimu.a /content/bart/src/simu/biot_savart.o
# ./ar_lock.sh rsU lib/libsimu.a /content/bart/src/simu/coil.o
# ./ar_lock.sh rsU lib/libsimu.a /content/bart/src/simu/bloch.o
# creating lib/libgrecon.a
# ar: creating lib/libsense.a
# ./ar_lock.sh rsU lib/libsimu.a /content/bart/src/simu/sens.o
# ar: ./ar_lock.sh rsU lib/libsimu.a /content/bart/src/simu/shape.o
# ./ar_lock.sh rsU lib/libnlops.a /content/bart/src/nlops/nltest.o
# ./ar_lock.sh rsU lib/libnlops.a /content/bart/src/nlops/cast.o
# creating lib/libnoir.a
# ./ar_lock.sh rsU lib/libnlops.a /content/bart/src/nlops/zexp.o
# ar: creating lib/libiter.a
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/recon_T2.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/moba.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/model_T1.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/model_T2.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/recon_T1.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/model_meco.o
# ./ar_lock.sh rsU lib/libgeom.a /content/bart/src/geom/triangle.o
# ./ar_lock.sh rsU lib/libgeom.a /content/bart/src/geom/logo.o
# ./ar_lock.sh rsU lib/libgeom.a /content/bart/src/geom/polyhedron.o
# ./ar_lock.sh rsU lib/libgeom.a /content/bart/src/geom/polygon.o
# ar: ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/iovec.o
# creating lib/liblinops.a
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/mem.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/specfun.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/init.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/vec3.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/qform.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/loop.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/fft-cuda.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/shuffle.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/gpuops.o
# ar: ar: creating lib/liblowrank.a
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/subpixel.o
# ar: creating lib/libwavelet.a
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/png.o
# creating lib/libcalib.a
# ar: ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/shrdptr.o
# creating lib/libnoncart.a
# ./ar_lock.sh rsU lib/libbox.a src/toimg.o
# ./ar_lock.sh rsU lib/libbox.a src/nlinv.o
# ./ar_lock.sh rsU lib/libbox.a src/wave.o
# ./ar_lock.sh rsU lib/libbox.a src/bin.o
# ar: creating lib/libsimu.a
# ./ar_lock.sh rsU lib/libbox.a src/twixread.o
# ./ar_lock.sh rsU lib/libbox.a src/signal.o
# ./ar_lock.sh rsU lib/libsense.a /content/bart/src/sense/optcom.o
# ar: ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/lsqr.o
# creating lib/libnlops.a
# ./ar_lock.sh rsU lib/libnoncart.a /content/bart/src/noncart/nudft.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/softweight.o
# ar: creating lib/libmoba.a
# ./ar_lock.sh rsU lib/libsimu.a /content/bart/src/simu/shepplogan.o
# ./ar_lock.sh rsU lib/libnlops.a /content/bart/src/nlops/tenmul.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/T2fun.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/T1fun.o
# ar: ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/casorati.o
# ar: creating lib/libnum.a
# creating lib/libgeom.a
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/rand.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/version.o
# ./ar_lock.sh rsU lib/libbox.a src/bench.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/lapack.o
# ./ar_lock.sh rsU lib/libsake.a /content/bart/src/sake/sake.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/ssa.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/bin.o
# ./ar_lock.sh rsU lib/libbox.a src/rtnlinv.o
# ar: ./ar_lock.sh rsU lib/libnoir.a /content/bart/src/noir/model.o
# creating lib/libmisc.a
# ./ar_lock.sh rsU lib/libbox.a src/traj.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/dicom.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/italgos.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/iter_l1.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/delays.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/utils.o
# ./ar_lock.sh rsU lib/libsimu.a /content/bart/src/simu/signals.o
# ar: creating lib/libsake.a
# ./ar_lock.sh rsU lib/liblowrank.a /content/bart/src/lowrank/lrthresh.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/blas.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/conv.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/finite_diff.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/debug.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/resize.o
# ./ar_lock.sh rsU lib/libbox.a src/poisson.o
# ./ar_lock.sh rsU lib/libbox.a src/moba.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/recon_meco.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/prox.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/estvar.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/ya_getopt.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/mri.o
# ./ar_lock.sh rsU lib/libdfwavelet.a /content/bart/src/dfwavelet/prox_dfwavelet.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/mdfft.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/linop.o
# ./ar_lock.sh rsU lib/libgrecon.a /content/bart/src/grecon/optreg.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/optreg.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/admm.o
# ./ar_lock.sh rsU lib/libiter.a /content/bart/src/iter/iter2.o
# ./ar_lock.sh rsU lib/libnlops.a /content/bart/src/nlops/chain.o
# ar: creating lib/libdfwavelet.a
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/opts.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/mmio.o
# ./ar_lock.sh rsU lib/libgeom.a /content/bart/src/geom/draw.o
# ./ar_lock.sh rsU lib/libbox.a src/sqpics.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/polynom.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/io.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/ops_p.o
# ./ar_lock.sh rsU lib/liblowrank.a /content/bart/src/lowrank/svthresh.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/filter.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/blockproc.o
# ./ar_lock.sh rsU lib/libbox.a src/pics.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/chebfun.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/misc.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/simplex.o
# ./ar_lock.sh rsU lib/libnoncart.a /content/bart/src/noncart/grid.o
# ./ar_lock.sh rsU lib/libsimu.a /content/bart/src/simu/phantom.o
# ./ar_lock.sh rsU lib/liblinops.a /content/bart/src/linops/someops.o
# ./ar_lock.sh rsU lib/libmoba.a /content/bart/src/moba/meco.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/optimize.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/convoaa.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/blas_md_wrapper.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/wavelet.o
# ./ar_lock.sh rsU lib/libbox.a src/wshfl.o
# ./ar_lock.sh rsU lib/libnlops.a /content/bart/src/nlops/nlop.o
# ./ar_lock.sh rsU lib/libwavelet.a /content/bart/src/wavelet/wavelet.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/fft.o
# ./ar_lock.sh rsU lib/libcalib.a /content/bart/src/calib/calib.o
# ./ar_lock.sh rsU lib/libnoncart.a /content/bart/src/noncart/nufft.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/vecops_strided.o
# ./ar_lock.sh rsU lib/libmisc.a /content/bart/src/misc/pd.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/ode.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/splines.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/linalg.o
# ./ar_lock.sh rsU lib/libdfwavelet.a /content/bart/src/dfwavelet/dfwavelet.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/vecops.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/ops.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/multind.o
# ./ar_lock.sh rsU lib/libnum.a /content/bart/src/num/flpmath.o
# gcc -rdynamic -O3 -ffast-math -Wmissing-prototypes -std=gnu11 -fopenmp -Wall -Wextra -MMD -MF ./.bart.d -iquote /content/bart/src/ -I/usr//include/ -I/usr//include -DFFTWTHREADS -DMAIN_LIST="avg, bench, bin, bitmask, cabs, caldir, calmat, carg, casorati, cc, ccapply, cdf97, circshift, conj, conv, conway, copy, cpyphs, creal, crop, delta, ecalib, ecaltwo, estdelay, estdims, estshift, estvar, extract, fakeksp, fft, fftmod, fftrot, fftshift, filter, flatten, flip, fmac, homodyne, index, invert, itsense, join, looklocker, lrmatrix, mandelbrot, mip, moba, mobafit, nlinv, noise, normalize, nrmse, nufft, ones, pattern, phantom, pics, pocsense, poisson, pol2mask, poly, repmat, reshape, resize, rmfreq, rof, roistat, rss, rtnlinv, sake, saxpy, scale, sdot, show, signal, slice, spow, sqpics, squeeze, ssa, std, svd, tgv, threshold, toimg, traj, transpose, twixread, upat, var, vec, version, walsh, wave, wavelet, wavepsf, whiten, window, wshfl, zeros, zexp, ()" -include src/main.h -Dmain_real=main_bart -o bart src/main.c /content/bart/src/bart.o lib/libbox.a lib/libgrecon.a lib/libsense.a lib/libnoir.a lib/libiter.a lib/liblinops.a lib/libwavelet.a lib/liblowrank.a lib/libnoncart.a lib/libcalib.a lib/libsimu.a lib/libsake.a lib/libdfwavelet.a lib/libnlops.a lib/libmoba.a lib/libgeom.a lib/libnum.a lib/libmisc.a lib/libnum.a lib/libmisc.a -L/usr//lib -lfftw3f -lfftw3f_threads  -L/usr//lib -llapacke -lblas -lpng   -lm
# ./rules/update_commands.sh ./bart doc/commands.txt avg bench bin bitmask cabs caldir calmat carg casorati cc ccapply cdf97 circshift conj conv conway copy cpyphs creal crop delta ecalib ecaltwo estdelay estdims estshift estvar extract fakeksp fft fftmod fftrot fftshift filter flatten flip fmac homodyne index invert itsense join looklocker lrmatrix mandelbrot mip moba mobafit nlinv noise normalize nrmse nufft ones pattern phantom pics pocsense poisson pol2mask poly repmat reshape resize rmfreq rof roistat rss rtnlinv sake saxpy scale sdot show signal slice spow sqpics squeeze ssa std svd tgv threshold toimg traj transpose twixread upat var vec version walsh wave wavelet wavepsf whiten window wshfl zeros zexp
# rm /content/bart/src/iter/monitor.o /content/bart/src/num/wavelet.o /content/bart/src/num/multind.o /content/bart/src/geom/polygon.o src/looklocker.o src/moba.o /content/bart/src/num/ode.o src/ecaltwo.o src/fftmod.o /content/bart/src/iter/iter.o /content/bart/src/noncart/nudft.o /content/bart/src/dfwavelet/prox_dfwavelet.o /content/bart/src/num/fft.o /content/bart/src/num/iovec.o /content/bart/src/num/loop.o /content/bart/src/misc/utils.o src/estdims.o /content/bart/src/iter/thresh.o /content/bart/src/iter/itop.o /content/bart/src/linops/waveop.o /content/bart/src/misc/misc.o /content/bart/src/noir/recon.o src/circshift.o /content/bart/src/calib/ssa.o /content/bart/src/lowrank/svthresh.o src/wavelet.o src/pol2mask.o /content/bart/src/misc/ya_getopt.o src/scale.o src/rtnlinv.o /content/bart/src/nlops/cast.o src/transpose.o /content/bart/src/num/ops_p.o /content/bart/src/num/linalg.o src/resize.o src/conway.o src/bench.o src/ecalib.o src/crop.o /content/bart/src/num/flpmath.o src/nrmse.o src/threshold.o /content/bart/src/geom/draw.o src/avg.o src/fft.o src/homodyne.o /content/bart/src/linops/linop.o /content/bart/src/geom/polyhedron.o /content/bart/src/geom/triangle.o /content/bart/src/iter/iter2.o /content/bart/src/misc/shrdptr.o src/saxpy.o src/mip.o src/window.o /content/bart/src/num/blas.o /content/bart/src/num/ops.o src/show.o /content/bart/src/iter/lsqr.o /content/bart/src/calib/walsh.o /content/bart/src/num/conv.o /content/bart/src/iter/niht.o /content/bart/src/iter/vec.o /content/bart/src/misc/mmio.o /content/bart/src/num/lapack.o /content/bart/src/misc/subpixel.o /content/bart/src/nlops/tenmul.o src/reshape.o /content/bart/src/iter/admm.o /content/bart/src/noir/model.o src/whiten.o src/rof.o /content/bart/src/nlops/chain.o src/rmfreq.o src/bin.o src/carg.o src/nufft.o /content/bart/src/num/shuffle.o src/signal.o /content/bart/src/num/filter.o /content/bart/src/nlops/nltest.o /content/bart/src/calib/estvar.o /content/bart/src/linops/fmac.o /content/bart/src/iter/italgos.o /content/bart/src/moba/T1fun.o src/conv.o /content/bart/src/linops/lintest.o /content/bart/src/calib/cc.o /content/bart/src/num/casorati.o src/fftrot.o src/poisson.o /content/bart/src/linops/sum.o /content/bart/src/num/blas_md_wrapper.o /content/bart/src/num/optimize.o /content/bart/src/geom/logo.o /content/bart/src/moba/recon_T2.o /content/bart/src/misc/opts.o src/upat.o src/mobafit.o /content/bart/src/linops/grad.o /content/bart/src/linops/sampling.o /content/bart/src/num/qform.o src/mandelbrot.o src/svd.o /content/bart/src/misc/resize.o /content/bart/src/simu/bloch.o src/version.o src/vec.o /content/bart/src/num/convoaa.o /content/bart/src/calib/softweight.o /content/bart/src/nlops/nlop.o src/fakeksp.o /content/bart/src/num/chebfun.o /content/bart/src/moba/optreg.o src/normalize.o /content/bart/src/grecon/optreg.o /content/bart/src/moba/iter_l1.o /content/bart/src/moba/model_T1.o src/repmat.o /content/bart/src/simu/coil.o /content/bart/src/num/mdfft.o src/ssa.o /content/bart/src/nlops/zexp.o /content/bart/src/sense/optcom.o src/ccapply.o /content/bart/src/iter/iter3.o src/var.o /content/bart/src/simu/phantom.o src/extract.o /content/bart/src/moba/moba.o /content/bart/src/calib/calmat.o src/index.o /content/bart/src/sense/model.o src/pattern.o /content/bart/src/moba/model_T2.o /content/bart/src/linops/someops.o src/filter.o /content/bart/src/num/vecops_strided.o /content/bart/src/lowrank/lrthresh.o /content/bart/src/simu/signals.o /content/bart/src/wavelet/wavthresh.o /content/bart/src/dfwavelet/dfwavelet.o /content/bart/src/num/splines.o /content/bart/src/moba/recon_meco.o src/walsh.o src/estdelay.o src/cabs.o /content/bart/src/iter/misc.o /content/bart/src/calib/delays.o /content/bart/src/iter/prox.o src/pocsense.o src/delta.o src/std.o src/bitmask.o src/squeeze.o src/cpyphs.o /content/bart/src/num/polynom.o src/fftshift.o /content/bart/src/grecon/italgo.o src/lrmatrix.o src/wave.o src/toimg.o src/caldir.o src/twixread.o src/estshift.o /content/bart ...
# make[1]: Leaving directory '/content/bart'

# %%
# !./bart bench
# Out:
#                 add (md_zaxpy) | 0.0360 0.0440 0.0349 0.0347 0.0348 | Avg: 0.0369 Max: 0.0440 Min: 0.0347
#     add (md_zaxpy), contiguous | 0.0035 0.0043 0.0027 0.0028 0.0027 | Avg: 0.0032 Max: 0.0043 Min: 0.0027
#                 add (for loop) | 0.0223 0.0197 0.0199 0.0205 0.0197 | Avg: 0.0204 Max: 0.0223 Min: 0.0197
#                 sum (md_zaxpy) | 0.1462 0.1452 0.1469 0.1461 0.1464 | Avg: 0.1462 Max: 0.1469 Min: 0.1452
#     sum (md_zaxpy), contiguous | 0.1623 0.1388 0.1536 0.1367 0.1340 | Avg: 0.1451 Max: 0.1623 Min: 0.1340
#                 sum (for loop) | 0.0111 0.0105 0.0111 0.0112 0.0125 | Avg: 0.0113 Max: 0.0125 Min: 0.0105
#       complex mult. (md_zmul2) | 0.0230 0.0212 0.0212 0.0212 0.0211 | Avg: 0.0216 Max: 0.0230 Min: 0.0211
#              complex transpose | 0.0511 0.0506 0.0506 0.0510 0.0600 | Avg: 0.0526 Max: 0.0600 Min: 0.0506
#                 complex resize | 0.0030 0.0033 0.0028 0.0029 0.0027 | Avg: 0.0029 Max: 0.0033 Min: 0.0027
#        complex matrix multiply | 0.0101 0.0021 0.0021 0.0021 0.0021 | Avg: 0.0037 Max: 0.0101 Min: 0.0021
#        batch matrix multiply 1 | 0.0326 0.0232 0.0230 0.0223 0.0222 | Avg: 0.0247 Max: 0.0326 Min: 0.0222
#        batch matrix multiply 2 | 0.0186 0.0180 0.0171 0.0169 0.0151 | Avg: 0.0172 Max: 0.0186 Min: 0.0151
#         tall matrix multiply 1 | 0.0068 0.0047 0.0050 0.0047 0.0047 | Avg: 0.0052 Max: 0.0068 Min: 0.0047
#         tall matrix multiply 2 | 0.0032 0.0034 0.0032 0.0032 0.0033 | Avg: 0.0032 Max: 0.0034 Min: 0.0032
#            complex dot product | 0.0178 0.0180 0.0136 0.0135 0.0139 | Avg: 0.0154 Max: 0.0180 Min: 0.0135
#            complex dot product | 0.0137 0.0138 0.0140 0.0136 0.0136 | Avg: 0.0137 Max: 0.0140 Min: 0.0136
#       real complex dot product | 0.0018 0.0018 0.0018 0.0017 0.0017 | Avg: 0.0018 Max: 0.0018 Min: 0.0017
#                        l2 norm | 0.0012 0.0012 0.0012 0.0012 0.0012 | Avg: 0.0012 Max: 0.0012 Min: 0.0012
#                        l1 norm | 0.0047 0.0052 0.0039 0.0057 0.0038 | Avg: 0.0047 Max: 0.0057 Min: 0.0038
#                         copy 1 | 0.0080 0.0081 0.0069 0.0071 0.0071 | Avg: 0.0074 Max: 0.0081 Min: 0.0069
#                         copy 2 | 0.0072 0.0072 0.0071 0.0073 0.0073 | Avg: 0.0072 Max: 0.0073 Min: 0.0071
#                   complex fill | 0.1781 0.1791 0.1683 0.1704 0.1700 | Avg: 0.1732 Max: 0.1791 Min: 0.1683
#  complex scalar multiplication | 0.0287 0.0345 0.0289 0.0313 0.0295 | Avg: 0.0306 Max: 0.0345 Min: 0.0287
#            wavelet soft thresh | 0.1353 0.1251 0.1264 0.1257 0.1269 | Avg: 0.1279 Max: 0.1353 Min: 0.1251
#                       (MD-)FFT | 0.0955 0.1086 0.0941 0.1030 0.1022 | Avg: 0.1007 Max: 0.1086 Min: 0.0941
#                            FFT | 0.1101 0.1037 0.1013 0.1098 0.0997 | Avg: 0.1049 Max: 0.1101 Min: 0.0997
#                         fftmod | 0.0755 0.0426 0.0439 0.0436 0.0429 | Avg: 0.0497 Max: 0.0755 Min: 0.0426

# %%
import os
import sys

os.environ['TOOLBOX_PATH'] = '/content/bart'
path = os.environ["TOOLBOX_PATH"] + "/python/"
sys.path.append(path)

# %%
from bart import bart
import cfl

# %%
x = bart(1, 'phantom')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.imshow(abs(x), cmap='gray')
